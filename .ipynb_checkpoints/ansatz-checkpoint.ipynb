# %%
import numpy as np 
import pandas as pd 
from tqdm import tqdm 
from discopro.grammar import tensor
from lambeq import BobcatParser, NumpyModel, AtomicType, Rewriter, Dataset, QuantumTrainer, SPSAOptimizer , AtomicType, IQPAnsatz, RemoveCupsRewriter
from lambeq.backend.grammar import Spider
from lambeq.rewrite import UnifyCodomainRewriter
from lambeq.backend.drawing import draw
from lambeq.backend.grammar import Ty
from tqdm import tqdm
import random
import datetime
from discopro.anaphora import connect_anaphora_on_top

# %%
remove_cups = RemoveCupsRewriter()

parser = BobcatParser()
rewriter = Rewriter(['auxiliary',
                     'connector',
                     'coordination',
                     'determiner',
                     'object_rel_pronoun',
                     'subject_rel_pronoun',
                     'postadverb',
                     'preadverb',
                     'prepositional_phrase'])

N = AtomicType.NOUN
S = AtomicType.SENTENCE
P = AtomicType.PREPOSITIONAL_PHRASE 
out = Ty('out')

ansatz = IQPAnsatz({N: 1, S: 1, P:1}, n_layers=1, n_single_qubit_params=3)

# %%
def generate_diagram(diagram, pro, ref):

    pro_box_idx = next(i for i, box in enumerate(diagram.boxes) if box.name.casefold() == pro.casefold())
    ref_box_idx = next(i for i, box in enumerate(diagram.boxes) if box.name.casefold() == ref.casefold())
    final_diagram = connect_anaphora_on_top(diagram, pro_box_idx, ref_box_idx)
    rewritten_diagram = rewriter(remove_cups(final_diagram)).normal_form()
    return rewritten_diagram

# %%
def sent2dig(sentence1: str, sentence2: str, pro: str, ref: str):
    diagram1 = parser.sentence2diagram(sentence1)
    diagram2 = parser.sentence2diagram(sentence2)
    diagram = tensor(diagram1,diagram2)
    #diagram = diagram >> Spider(S, 2, 1)
    diagram = generate_diagram(diagram, pro, ref)
    #merger = UnifyCodomainRewriter(Ty('s'))
    #diagram = merger(diagram)
    return diagram

# %%
tmp = sent2dig("The fish ate the bug", "It was satisfied", "It", "fish").draw(space=10,figsize=(12,4))

# %%
def gen_labels(df: pd.DataFrame):
    circuits, labels, diagrams = [],[],[]
    selected_cols = [random.choice(['referent', 'wrong_referent']) for i in range(len(df))]

    #for i, row in tqdm(df.iterrows(), total=len(df)):
    for i in range(10):
        row = df.iloc[i]
        ref1 = row[selected_cols[i] + '1']
        ref2 = row[selected_cols[i] + '2']
        #label = [1.0, 0.0] if i % 2 == 0 else [0.0, 1.0]
        label = [1.0, 0.0] if selected_cols[i] == 'referent' else [0.0, 1.0]
        sent1, sent21, sent22, pro = row[['sentence1', 'sentence21', 'sentence22', 'pronoun']]
        #sent21 = sent21.replace(pro, 'The ' + ref1)
        #sent22 = sent22.replace(pro, 'The' + ref2)

        try:
            diagram1 = sent2dig(sent1.strip(), sent21.strip())
            diagram2 = sent2dig(sent1.strip(), sent22.strip())
            diagrams.append((diagram1, diagram2))
            discopy_circuit1 = ansatz(diagram1)
            discopy_circuit2 = ansatz(diagram2)
            circuits.append((discopy_circuit1, discopy_circuit2))
            labels.append((label,label))
        except Exception as e:
            # Print an error message if an exception occurs
            print("An error occurred:", e)

    return circuits, labels, diagrams

# %%
def gen_labels(df: pd.DataFrame):
    circuits, labels, diagrams = [],[],[]
    selected_cols = [random.choice(['referent', 'wrong_referent']) for i in range(len(df))]
    for i, row in tqdm(df.iterrows(), total=len(df)):
        ref = row[selected_cols[i]]
        label = [[0.25, 0.25],[0.25, 0.25]] if selected_cols[i] == 'referent' else [[0.25, 0.25],[0.25, 0.25]]
        sent1, sent2, pro = row[['sentence1', 'sentence2', 'pronoun']]

        try:
            diagram = sent2dig(sent1.strip(), sent2.strip(), pro.strip(), ref.strip())
            diagrams.append(diagram)
            circ = ansatz(diagram)
            circuits.append(circ)
            labels.append(label)
        except Exception as e:
            print("Error: ", e)
    return circuits, labels, diagrams

# %%
# df_train = pd.read_csv('dataset/train_60.csv', index_col=0)
# df_val = pd.read_csv('dataset/valid_20.csv', index_col=0)
# df_test = pd.read_csv('dataset/test_20.csv', index_col=0)
df_train = pd.read_csv('dataset/original_data/train.csv', index_col=0)
df_val = pd.read_csv('dataset/original_data/val.csv', index_col=0)
df_test = pd.read_csv('dataset/original_data/test.csv', index_col=0)

# %%
train_circuits, train_labels, train_diagrams = gen_labels(df_train[:10])
val_circuits, val_labels, val_diagrams = gen_labels(df_val[:10])
test_circuits, test_labels, test_diagrams = gen_labels(df_test[:10])
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:04<00:00,  2.23it/s]
#  20%|██████████████████████████                                                                                                        | 2/10 [00:00<00:03,  2.44it/s]
# Error:  Diagram 0 (cod=n @ n.r @ n @ n) does not compose with diagram 1 (dom=n @ p.r @ n)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:04<00:00,  2.25it/s]
# Error:  Diagram 0 (cod=) does not compose with diagram 1 (dom=qubit)
#  20%|██████████████████████████                                                                                                        | 2/10 [00:00<00:03,  2.32it/s]
# Error:  Diagram 0 (cod=) does not compose with diagram 1 (dom=qubit)
#  50%|█████████████████████████████████████████████████████████████████                                                                 | 5/10 [00:02<00:02,  2.44it/s]
# Error:  Diagram 0 (cod=) does not compose with diagram 1 (dom=qubit)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:04<00:00,  2.38it/s]

# %%
from pytket.circuit.display import render_circuit_jupyter
tket_circuit = train_circuits[0].to_tk()
render_circuit_jupyter(tket_circuit)

# %%
from pytket.extensions.qiskit import tk_to_qiskit
tk_to_qiskit(tket_circuit).draw(output="mpl")

# %%
from lambeq.training import BinaryCrossEntropyLoss
all_circuits = train_circuits + val_circuits + test_circuits
model = NumpyModel.from_diagrams(all_circuits, use_jit=True)
loss = lambda y_hat, y: -np.sum(y * np.log(y_hat)) / len(y)  # binary cross-entropy loss
#loss = BinaryCrossEntropyLoss(sparse=False)
acc = lambda y_hat, y: np.sum(np.round(y_hat) == np.array(y)) / len(y) / 2  # half due to double-counting
eval_metrics = {"acc": acc}

# %%
def BinaryCrossEntropy(y_pred, y_true):
    term_0 = (1-y_true) * np.log(1-y_pred)
    term_1 = y_true * np.log(y_pred)
    return -np.mean(term_0+term_1)
loss = BinaryCrossEntropy

# %%
def main(EPOCHS: int, SEED: int, BATCH_SIZE: int) -> None:

    trainer = QuantumTrainer(
        model,
        loss_function=loss,
        epochs=EPOCHS,
        optimizer=SPSAOptimizer,
        optim_hyperparams={'a': 0.1, 'c': 0.06, 'A': 0.01 * EPOCHS},
        evaluate_functions=eval_metrics,
        evaluate_on_train=True,
        verbose='text',
        seed=SEED)

    train_dataset = Dataset(train_circuits, train_labels, batch_size=BATCH_SIZE)
    val_dataset = Dataset(val_circuits, val_labels, shuffle=False)

    now = datetime.datetime.now()
    t = now.strftime("%Y-%m-%d_%H_%M_%S")
    print(t)
    trainer.fit(train_dataset, val_dataset, eval_interval=1, log_interval=1)
    test_acc = acc(model(test_circuits), test_labels)
    print('Test accuracy:', test_acc)

# %%
seed_arr = [0, 10, 50, 77, 100, 111, 150, 169, 200, 234, 250, 300, 350, 400, 450]
B_sizes = [2]
epochs_arr = [2000]

# %%
SEED = random.choice(seed_arr)
BATCH_SIZE = 5
EPOCHS = 100

# %%
main(EPOCHS, SEED, BATCH_SIZE)
# Out:
# 2024-06-21_14_15_09
# Epoch 1:    train/loss: 0.8176   valid/loss: 0.8152   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 2:    train/loss: 0.7449   valid/loss: 0.8528   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 3:    train/loss: 0.7629   valid/loss: 0.8561   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 4:    train/loss: 0.7029   valid/loss: 0.8492   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 5:    train/loss: 0.7138   valid/loss: 0.8810   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 6:    train/loss: 0.6789   valid/loss: 0.8233   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 7:    train/loss: 0.6935   valid/loss: 0.8046   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 8:    train/loss: 0.6606   valid/loss: 0.8311   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 9:    train/loss: 0.6655   valid/loss: 0.8157   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 10:   train/loss: 0.6457   valid/loss: 0.8367   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 11:   train/loss: 0.6139   valid/loss: 0.8358   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 12:   train/loss: 0.6154   valid/loss: 0.8048   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 13:   train/loss: 0.6375   valid/loss: 0.7911   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 14:   train/loss: 0.6586   valid/loss: 0.7938   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 15:   train/loss: 0.6746   valid/loss: 0.7936   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 16:   train/loss: 0.6605   valid/loss: 0.7889   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 17:   train/loss: 0.6434   valid/loss: 0.7883   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 18:   train/loss: 0.7483   valid/loss: 0.7942   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 19:   train/loss: 0.6272   valid/loss: 0.8034   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 20:   train/loss: 0.6200   valid/loss: 0.7989   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 21:   train/loss: 0.6510   valid/loss: 0.7882   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 22:   train/loss: 0.6331   valid/loss: 0.7843   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 23:   train/loss: 0.6366   valid/loss: 0.7941   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 24:   train/loss: 0.6558   valid/loss: 0.7956   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 25:   train/loss: 0.6480   valid/loss: 0.7961   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 26:   train/loss: 0.6444   valid/loss: 0.7835   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 27:   train/loss: 0.6218   valid/loss: 0.7828   train/acc: 0.0000   valid/acc: 0.0000
# Epoch
train/acc: 0.0000   valid/acc: 0.0000
# Epoch 79:   train/loss: 0.6106   valid/loss: 0.7973   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 80:   train/loss: 0.5830   valid/loss: 0.7994   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 81:   train/loss: 0.6333   valid/loss: 0.7946   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 82:   train/loss: 0.6226   valid/loss: 0.7927   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 83:   train/loss: 0.6074   valid/loss: 0.7955   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 84:   train/loss: 0.5874   valid/loss: 0.7939   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 85:   train/loss: 0.6133   valid/loss: 0.7928   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 86:   train/loss: 0.5951   valid/loss: 0.7914   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 87:   train/loss: 0.6157   valid/loss: 0.7896   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 88:   train/loss: 0.6178   valid/loss: 0.7897   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 89:   train/loss: 0.5941   valid/loss: 0.7898   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 90:   train/loss: 0.5965   valid/loss: 0.7899   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 91:   train/loss: 0.6022   valid/loss: 0.7878   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 92:   train/loss: 0.6020   valid/loss: 0.7916   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 93:   train/loss: 0.5933   valid/loss: 0.7914   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 94:   train/loss: 0.5924   valid/loss: 0.7918   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 95:   train/loss: 0.5975   valid/loss: 0.7941   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 96:   train/loss: 0.5874   valid/loss: 0.7938   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 97:   train/loss: 0.6049   valid/loss: 0.8002   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 98:   train/loss: 0.5986   valid/loss: 0.8026   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 99:   train/loss: 0.6314   valid/loss: 0.8025   train/acc: 0.0000   valid/acc: 0.0000
# Epoch 100:  train/loss: 0.5925   valid/loss: 0.8066   train/acc: 0.0000   valid/acc: 0.0000
#
# Training completed!
# Test accuracy: 0.0

# %%
for SEED in seed_arr:
    for BATCH_SIZE in B_sizes:
        for EPOCHS in epochs_arr:
            print(EPOCHS, SEED, BATCH_SIZE)
            main(EPOCHS, SEED, BATCH_SIZE)

# %%
s1, s2, p, n = df_train.iloc[3][['sentence1','sentence2','pronoun','referent']]
print(s1, s2, p, n)
# Out:
# The determined birds devoured the chewy seeds They were a dessert They seeds

# %%
best_model = NumpyModel.from_checkpoint('runs/Jun18_11-50-11_TLS-MBP.local/best_model.lt')
best_model.initialise_weights()

# %%
diag = ansatz(sent2dig(s1, s2, p, n))
diagXX = diag
diagZX = diag
diagXZ = diag
diagZZ = diag

# %%
from qiskit.circuit.library import RYGate, HGate
from lambeq.backend.quantum import Box, qubit, SelfConjugate
ry = RYGate(0).to_matrix()
h = HGate().to_matrix()

# %%
diag.apply_gate(SelfConjugate(name='RY',dom=qubit,cod=qubit),0)
diag.draw(figsize=(16, 8))
# diagXZ.apply_gate(Box(name='RY',dom=qubit,cod=qubit,data=ry),1)
# diagXZ.apply_gate(Box(name='H',dom=qubit,cod=qubit,data=h),1)

# diagZZ.apply_gate(Box(name='RY',dom=qubit,cod=qubit,data=ry),1)
# diagZZ.apply_gate(Box(name='H',dom=qubit,cod=qubit,data=h),0)
# diagZZ.apply_gate(Box(name='H',dom=qubit,cod=qubit,data=h),1)

# %%
probabilities = best_model.get_diagram_output([diag])[0]
print(probabilities)
# Out:
# [[0.40942953 0.40327109]
#  [0.10819533 0.07910405]]
